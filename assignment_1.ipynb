# %% [markdown]
# ## 1: Checks the temperature and prints a corresponding message.

# %%
temp = int(input("Enter the current temperature in Celsius: "))

if temp < 10:
    print("It's too cold!")
elif temp <= 25:
    print("It's cool outside")
else:
    print("It's hot outside!")
# Out:
# Enter the current temperature in Celsius:  30
# It's hot outside!

# %% [markdown]
# ## 2: ATM Withdrawal System

# %%
balance = float(input("Enter your current account balance: BDT "))
withdrawal = float(input("Enter the amount you want to withdraw: BDT "))

if withdrawal > balance:
    print("Insufficient Balance")
else:
    remaining_balance = balance - withdrawal
    print("Transaction Successful!")
    print(f"Remaining Balance: BDT {remaining_balance:.2f}")
# Out:
# Enter your current account balance: BDT  200
# Enter the amount you want to withdraw: BDT  45
# Transaction Successful!
# Remaining Balance: BDT 155.00

# %% [markdown]
# ## 3: Calculates a student's grade based on marks (0-100)

# %%
marks = int(input("Enter student's marks (0-100): "))

if not (0 <= marks <= 100):
    print("Marks must be between 0 and 100.")
if marks >= 90:
    print("Grade: A+")
elif marks >= 80: 
    print("Grade: A")
elif marks >= 70: 
    print("Grade: B")
elif marks >= 60: 
    print("Grade: C ")
else: # Below 60
    print("Grade: Fail")
# Out:
# Enter student's marks (0-100):  60
# Grade: C

# %% [markdown]
#  ## 4: Calculates bus ticket price based on age discounts

# %%
age = int(input("Enter the user's age: "))
ticket_price = 100 

if age < 5:
    price_status = "Free"
    final_price = 0
elif age <= 18: 
    price_status = "50% Discount"
    final_price = ticket_price * 0.50
elif age >= 60:
    price_status = "30% Discount"
    final_price = ticket_price * 0.70
else:
    price_status = "Full Price"
    final_price = ticket_price

print(f"Final Ticket Price: BDT {final_price:.2f}")
# Out:
# Enter the user's age:  55
# Final Ticket Price: BDT 100.00

# %% [markdown]
# ## 5: Applies a 10% discount if the bill is over 1000

# %%
bill_amount = float(input("Enter the total bill amount: BDT "))
discount_rate = 0.0

if bill_amount > 1000:
    discount_rate = 0.10
    discount_amount = bill_amount * discount_rate
    final_bill = bill_amount - discount_amount
else:
    final_bill = bill_amount
    print("No discount applied (Bill under 1000).")

print(f"Total Payable Amount: BDT {final_bill:.2f}")
# Out:
# Enter the total bill amount: BDT  2000
# Discount Applied: 10% (BDT 200.00)
# Total Payable Amount: BDT 1800.00

# %% [markdown]
# ## 6: Simple login check using 'and'

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "12345":
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username:  admin
# Enter password:  12345
# Login Successful

# %% [markdown]
# ## 7: Prints action based on the input traffic light color.

# %%
color = input("Enter the traffic light color (red, yellow, or green): ").lower()

if color == "red":
    print("Stop")
elif color == "yellow":
    print("Ready to go")
elif color == "green":
    print("Go")
else:
    print("Invalid color. Please enter red, yellow, or green.")
# Out:
# Enter the traffic light color (red, yellow, or green):  yellow
# Ready to go

# %% [markdown]
# ## 8: Determines if a year is a leap year using the standard rules.

# %%
year = int(input("Enter a year: "))

if year % 400 == 0:
    print(f"{year} is a Leap Year!")
elif (year % 4 == 0) and (year % 100 != 0):
    print(f"{year} is a Leap Year!")
else:
    print(f"{year} is Not a Leap Year")
# Out:
# Enter a year:  2003
# 2003 is Not a Leap Year

# %% [markdown]
# ## 9: Checks eligibility based on age and qualification.

# %%
age = int(input("Enter age: "))
qualification = input("Enter qualification (e.g., graduate): ").strip().lower()

if age >= 18 and qualification == "graduate":
    print("Eligible for Job")
else:
    print("Not Eligible")
# Out:
# Enter age:  12

# %% [markdown]
# ## 10. Electricity Bill Calculator

# %%
units = int(input("Enter number of units consumed: "))
total_bill = 0

if units <= 100:
    total_bill = units * 5
elif units <= 200:
    bill_for_100 = 100 * 5 
    remaining_units = units - 100
    bill_for_rest = remaining_units * 7
    total_bill = bill_for_100 + bill_for_rest
else:
    bill_for_100 = 100 * 5
    bill_for_next_100 = 100 * 7
    remaining_units = units - 200
    bill_for_rest = remaining_units * 10
    total_bill = bill_for_100 + bill_for_next_100 + bill_for_rest

print(f"Total Payable Amount: BDT {total_bill:.2f}")
# Out:
# Enter number of units consumed:  50
# Total Units Consumed: 50
# Total Payable Amount: BDT 250.00
